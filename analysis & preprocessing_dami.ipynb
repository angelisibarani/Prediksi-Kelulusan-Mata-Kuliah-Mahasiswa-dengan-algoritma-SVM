# %% [markdown]
# Noel Christoper Butarbutar (12S16033)
#
# Lavenia Situmorang (12S17003)
#
# Ruth Angeli Sibarani (12S17052)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing

import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns

# %% [markdown]
# # Data Understanding

# %%
df = pd.read_csv("D:/Materi Kuliah/Semester 9/DAMI2/proyek akhir/uc_club.csv")
df = df[:20001]
df.head()
# Out:
#    ceeb_id                        fullname         campus           city.x  \
# 0      470          NATIONAL UNIVERSITY470      San Diego         La Jolla
# 1      933  COASTLINE COMMUNITY COLLEGE933       Berkeley  Fountain Valley
# 2      933  COASTLINE COMMUNITY COLLEGE933    Los Angeles  Fountain Valley
# 3      933  COASTLINE COMMUNITY COLLEGE933  Santa Barbara  Fountain Valley
# 4      933  COASTLINE COMMUNITY COLLEGE933      Riverside  Fountain Valley
#
#   fall_term                  school_name ethcat  app_val  adm_val  enr_val  \
# 0  9/1/2013          NATIONAL UNIVERSITY  White        6        0        0
# 1  9/1/2015  COASTLINE COMMUNITY COLLEGE  Asian       10        0        0
# 2  9/1/2015  COASTLINE COMMUNITY COLLEGE  White        7        0        0
# 3  9/1/2015  COASTLINE COMMUNITY COLLEGE  Asian       12        6        0
# 4  9/1/2016  COASTLINE COMMUNITY COLLEGE  Asian       15        4        0
#
#    app_gpa  adm_gpa  enr_gpa  col_lat  col_long  col_rank    sch_lat  \
# 0      NaN      NaN      NaN  32.8801 -117.2340         3  32.829481
# 1      NaN      NaN      NaN  37.8719 -122.2585         1  33.715600
# 2      NaN      NaN      NaN  34.0689 -118.4452         2  33.715600
# 3      NaN      NaN      NaN  34.4140 -119.8489         5  33.715600
# 4      NaN      NaN      NaN  33.9737 -117.3281         8  33.715600
#
#      sch_long           d
# 0 -117.127251   11.464280
# 1 -117.929238  605.606830
# 2 -117.929238   61.811813
# 3 -117.929238  193.361754
# 4 -117.929238   62.572713

# %%
#check for null values
print(df.isnull().sum())
# Out:
# ceeb_id            0
# fullname           0
# campus             0
# city.x             0
# fall_term          0
# school_name        0
# ethcat             0
# app_val            0
# adm_val            0
# enr_val            0
# app_gpa        20001
# adm_gpa        20001
# enr_gpa        20001
# col_lat            0
# col_long           0
# col_rank           0
# sch_lat            0
# sch_long           0
# d                  0
# dtype: int64

# %%
#drop the clumn with NAN values
df = df.dropna(axis='columns')

# %%
df.head()
# Out:
#    ceeb_id                        fullname         campus           city.x  \
# 0      470          NATIONAL UNIVERSITY470      San Diego         La Jolla
# 1      933  COASTLINE COMMUNITY COLLEGE933       Berkeley  Fountain Valley
# 2      933  COASTLINE COMMUNITY COLLEGE933    Los Angeles  Fountain Valley
# 3      933  COASTLINE COMMUNITY COLLEGE933  Santa Barbara  Fountain Valley
# 4      933  COASTLINE COMMUNITY COLLEGE933      Riverside  Fountain Valley
#
#   fall_term                  school_name ethcat  app_val  adm_val  enr_val  \
# 0  9/1/2013          NATIONAL UNIVERSITY  White        6        0        0
# 1  9/1/2015  COASTLINE COMMUNITY COLLEGE  Asian       10        0        0
# 2  9/1/2015  COASTLINE COMMUNITY COLLEGE  White        7        0        0
# 3  9/1/2015  COASTLINE COMMUNITY COLLEGE  Asian       12        6        0
# 4  9/1/2016  COASTLINE COMMUNITY COLLEGE  Asian       15        4        0
#
#    col_lat  col_long  col_rank    sch_lat    sch_long           d
# 0  32.8801 -117.2340         3  32.829481 -117.127251   11.464280
# 1  37.8719 -122.2585         1  33.715600 -117.929238  605.606830
# 2  34.0689 -118.4452         2  33.715600 -117.929238   61.811813
# 3  34.4140 -119.8489         5  33.715600 -117.929238  193.361754
# 4  33.9737 -117.3281         8  33.715600 -117.929238   62.572713

# %%
df.describe()
# Out:
#             ceeb_id       app_val       adm_val       enr_val       col_lat  \
# count  20001.000000  20001.000000  20001.000000  20001.000000  20001.000000
# mean    4107.580421     28.814459     14.942603      4.870806     35.361651
# std      324.021944     42.451251     23.297747     10.479280      2.026321
# min      470.000000      5.000000      0.000000      0.000000     32.880100
# 25%     4052.000000      8.000000      4.000000      0.000000     33.973700
# 50%     4109.000000     14.000000      7.000000      0.000000     34.414000
# 75%     4302.000000     31.000000     17.000000      5.000000     37.871900
# max     4388.000000    546.000000    319.000000    160.000000     38.538200
#
#            col_long      col_rank       sch_lat      sch_long             d
# count  20001.000000  20001.000000  20001.000000  20001.000000  20001.000000
# mean    -119.623791      4.455477     35.671071   -119.716292    291.662186
# std        1.979954      2.402172      1.926756      2.043368    231.509527
# min     -122.258500      1.000000     32.744744   -124.195310      7.524706
# 25%     -121.761700      2.000000     33.884924   -122.045055     81.112190
# 50%     -119.848900      4.000000     34.944613   -118.971805    202.791980
# 75%     -117.844300      6.000000     37.447935   -118.003830    514.889501
# max     -117.234000      9.000000     41.412319   -111.649316   1077.955083

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20001 entries, 0 to 20000
# Data columns (total 16 columns):
# ceeb_id        20001 non-null int64
# fullname       20001 non-null object
# campus         20001 non-null object
# city.x         20001 non-null object
# fall_term      20001 non-null object
# school_name    20001 non-null object
# ethcat         20001 non-null object
# app_val        20001 non-null int64
# adm_val        20001 non-null int64
# enr_val        20001 non-null int64
# col_lat        20001 non-null float64
# col_long       20001 non-null float64
# col_rank       20001 non-null int64
# sch_lat        20001 non-null float64
# sch_long       20001 non-null float64
# d              20001 non-null float64
# dtypes: float64(5), int64(5), object(6)
# memory usage: 2.4+ MB

# %%
#check for duplicate value
duplicate_rows_df = df[df.duplicated()]
print('number of duplicate rows: ', duplicate_rows_df.shape)
# Out:
# ('number of duplicate rows: ', (0, 16))

# %%
# Check for correlations among columns
plt.subplots(figsize=(10,8))
sns.heatmap(df.corr(), annot=True);

# %%
for rating in sorted(df['col_rank'].unique()):
    print "college ranking: ", rating, "\n"
    print df[df['col_rank']==rating].describe(), 2*"\n"
# Out:
# college ranking:  1
#
#            ceeb_id      app_val      adm_val      enr_val       col_lat  \
# count  2671.000000  2671.000000  2671.000000  2671.000000  2.671000e+03
# mean   4111.409210    31.981655     9.098465     6.269562  3.787190e+01
# std     301.140435    46.728437    15.536126    12.679009  1.428458e-12
# min     933.000000     5.000000     0.000000     0.000000  3.787190e+01
# 25%    4052.000000     8.000000     0.000000     0.000000  3.787190e+01
# 50%    4109.000000    15.000000     4.000000     3.000000  3.787190e+01
# 75%    4296.000000    35.000000    10.000000     6.000000  3.787190e+01
# max    4388.000000   410.000000   143.000000   124.000000  3.787190e+01
#
#            col_long  col_rank      sch_lat     sch_long            d
# count  2.671000e+03    2671.0  2671.000000  2671.000000  2671.000000
# mean  -1.222585e+02       1.0    35.885766  -119.939527   330.781275
# std    2.615287e-12       0.0     1.967653     2.075309   256.815986
# min   -1.222585e+02       1.0    32.744744  -124.195310    10.313065
# 25%   -1.222585e+02       1.0    33.886374  -122.071291    58.135778
# 50%   -1.222585e+02       1.0    35.407914  -119.797870   313.914068
# 75%   -1.222585e+02       1.0    37.656345  -118.025093   581.201560
# max   -1.222585e+02       1.0    41.412319  -111.649316   953.927770
#
#
# college ranking:  2
#
#            ceeb_id      app_val      adm_val      enr_val       col_lat  \
# count  2858.000000  2858.000000  2858.000000  2858.000000  2.858000e+03
# mean   4096.171099    34.818754    11.872638     6.431421  3.406890e+01
# std     347.853173    48.554687    17.240700    10.533096  1.307627e-12
# min     933.000000     5.000000     0.000000     0.000000  3.406890e+01
# 25%    4052.000000     9.000000     3.000000     0.000000  3.406890e+01
# 50%    4104.000000    17.000000     6.000000     3.000000  3.406890e+01
# 75%    4296.000000    40.000000    14.000000     8.000000  3.406890e+01
# max    4388.000000   441.000000   145.000000    82.000000  3.406890e+01
#
#            col_long  col_rank      sch_lat     sch_long            d
# count  2.858000e+03    2858.0  2858.000000  2858.000000  2858.000000
# mean  -1.184452e+02       2.0    35.530325  -119.559388   256.072871
# std    6.822404e-13       0.0     1.878780     2.027103   219.737580
# min   -1.184452e+02       2.0    32.744744  -124.195310    22.738002
# 25%   -1.184452e+02       2.0    33.884924  -121.924629    53.271750
# 50%   -1.184452e+02       2.0    34.676982  -118.568230   193.315136
# 75%   -1.184452e+02       2.0    37.360278  -117.917577   494.893443
# max   -1.184452e+02       2.0    40.875275  -111.649316   914.484779
#
#
# college ranking:  3
#
#            ceeb_id      app_val      adm_val      enr_val       col_lat  \
# count  2418.000000  2418.000000  2418.000000  2418.000000  2.418000e+03
# mean   4110.031431    30.638958    17.631514     4.805624  3.288010e+01
# std     325.986254    45.332102    27.916868    10.172501  2.842759e-13
# min     470.000000     5.000000     0.000000     0.000000  3.288010e+01
# 25%    4052.000000     8.000000     4.000000     0.000000  3.288010e+01
# 50%    4117.000000    15.000000     9.000000     0.000000  3.288010e+01
# 75%    4302.000000    33.000000    19.000000     5.000000  3.288010e+01
# max    4388.000000   493.000000   263.000000   101.000000  3.288010e+01
#
#            col_long  col_rank      sch_lat     sch_long            d
# count  2.418000e+03    2418.0  2418.000000  2418.000000  2418.000000
# mean  -1.172340e+02       3.0    35.490299  -119.532948   369.816456
# std    2.828545e-12       0.0     1.933419     2.078165   270.878970
# min   -1.172340e+02       3.0    32.744744  -124.195310    11.464280
# 25%   -1.172340e+02       3.0    33.884924  -122.045055   137.664102
# 50%   -1.172340e+02       3.0    34.676982  -118.568230   218.593600
# 75%   -1.172340e+02       3.0    37.360278  -117.917577   668.574556
# max   -1.172340e+02       3.0    41.412319  -111.649316  1077.955083
#
#
# college ranking:  4
#
#            ceeb_id      app_val      adm_val      enr_val       col_lat  \
# count  2387.000000  2387.000000  2387.000000  2387.000000  2.387000e+03
# mean   4123.112275    31.878090    20.731881     7.534981  3.853820e+01
# std     256.676724    52.708921    35.969080    15.064236  4.548426e-13
# min     933.000000     5.000000     0.000000     0.000000  3.853820e+01
# 25%    4052.000000     8.000000     5.000000     0.000000  3.853820e+01
# 50%    4117.000000    14.000000     9.000000     3.000000  3.853820e+01
# 75%    4296.000000    30.000000    19.000000     7.000000  3.853820e+01
# max    4388.000000   546.000000   319.000000   128.000000  3.853820e+01
#
#            col_long  col_rank      sch_lat     sch_long            d
# count  2.387000e+03    2387.0  2387.000000  2387.000000  2387.000000
# mean  -1.217617e+02       4.0    36.248862  -120.251836   326.579298
# std    5.116980e-13       0.0     2.003409     1.980587   240.441385
# min   -1.217617e+02       4.0    32.744744  -124.195310    31.041647
# 25%   -1.217617e+02       4.0    34.135553  -122.071291   122.477932
# 50%   -1.217617e+02       4.0    36.766892  -120.740073   262.382365
# 75%   -1.217617e+02       4.0    37.784564  -118.186258   600.787552
# max   -1.217617e+02       4.0    41.412319  -115.503774   850.616708
#
#
# college ranking:  5
#
#            ceeb_id      app_val      adm_val      enr_val       col_lat  \
# count  2445.000000  2445.000000  2445.000000  2445.000000  2.445000e+03
# mean   4110.953374    27.177914    16.026176     2.961145  3.441400e+01
# std     300.350130    35.220870    20.306856     4.750885  1.421376e-14
# min     933.000000     5.000000     0.000000     0.000000  3.441400e+01
# 25%    4052.000000     8.000000     5.000000     0.000000  3.441400e+01
# 50%    4109.000000    15.000000     9.000000     0.000000  3.441400e+01
# 75%    4302.000000    32.000000    20.000000     4.000000  3.441400e+01
# max    4388.000000   408.000000   194.000000    31.000000  3.441400e+01
#
#            col_long  col_rank      sch_lat     sch_long            d
# count  2.445000e+03    2445.0  2445.000000  2445.000000  2445.000000
# mean  -1.198489e+02       5.0    35.646670  -119.720663   279.716791
# std    2.586905e-12       0.0     1.906049     2.010585   138.726070
# min   -1.198489e+02       5.0    32.744744  -124.195310    78.824411
# 25%   -1.198489e+02       5.0    33.886374  -122.045055   162.010802
# 50%   -1.198489e+02       5.0    34.944613  -118.971805   218.215510
# 75%   -1.198489e+02       5.0    37.360278  -118.003830   387.003673
# max   -1.198489e+02       5.0    41.412319  -115.503774   810.350249
#
#
# college ranking:  6
#
#            ceeb_id      app_val      adm_val      enr_val       col_lat  \
# count  2384.000000  2384.000000  2384.000000  2384.000000  2.384000e+03
# mean   4071.634228    32.436661    17.909815     4.940856  3.364050e+01
# std     431.142628    45.663838    25.071159     9.261634  2.913836e-13
# min     933.000000     5.000000     0.000000     0.000000  3.364050e+01
# 25%    4051.000000     8.000000     4.000000     0.000000  3.364050e+01
# 50%    4104.000000    16.000000     9.000000     0.000000  3.364050e+01
# 75%    4302.000000    37.250000    21.000000     6.000000  3.364050e+01
# max    4381.000000   466.000000   195.000000    98.000000  3.364050e+01
#
#            col_long  col_rank      sch_lat     sch_long            d
# count  2.384000e+03    2384.0  2384.000000  2384.000000  2384.000000
# mean  -1.178443e+02       6.0    35.273915  -119.307455   248.669223
# std    2.572704e-12       0.0     1.797033     1.938221   244.122046
# min   -1.178443e+02       6.0    32.744744  -124.195310     7.524706
# 25%   -1.178443e+02       6.0    33.875251  -121.478178    46.483421
# 50%   -1.178443e+02       6.0    34.166361  -118.228403   119.615468
# 75%   -1.178443e+02       6.0    37.319540  -117.917577   559.154670
# max   -1.178443e+02       6.0    40.875275  -115.503774   976.030784
#
#
# college ranking:  7
#
#            ceeb_id      app_val      adm_val      enr_val       col_lat  \
# count  2026.000000  2026.000000  2026.000000  2026.000000  2.026000e+03
# mean   4130.596249    23.354886    15.560217     4.189042  3.698810e+01
# std     265.896306    33.256384    23.449438    12.089473  1.030541e-12
# min     933.000000     5.000000     0.000000     0.000000  3.698810e+01
# 25%    4061.000000     7.000000     5.000000     0.000000  3.698810e+01
# 50%    4117.000000    12.000000     8.000000     0.000000  3.698810e+01
# 75%    4302.000000    24.000000    17.000000     4.000000  3.698810e+01
# max    4388.000000   327.000000   231.000000   160.000000  3.698810e+01
#
#            col_long  col_rank      sch_lat     sch_long            d
# count  2.026000e+03    2026.0  2026.000000  2026.000000  2026.000000
# mean  -1.220582e+02       7.0    36.090014  -120.218806   273.262476
# std    4.832883e-13       0.0     1.930763     2.011142   205.883008
# min   -1.220582e+02       7.0    32.744744  -124.195310    11.878156
# 25%   -1.220582e+02       7.0    34.039642  -122.071291    65.650444
# 50%   -1.220582e+02       7.0    36.766892  -120.740073   202.791980
# 75%   -1.220582e+02       7.0    37.535051  -118.148088   483.536797
# max   -1.220582e+02       7.0    41.412319  -115.503774   756.341786
#
#
# college ranking:  8
#
#            ceeb_id      app_val      adm_val      enr_val       col_lat  \
# count  2094.000000  2094.000000  2094.000000  2094.000000  2.094000e+03
# mean   4100.380611    19.790831    14.147564     2.422636  3.397370e+01
# std     338.661815    21.074191    14.761221     4.094265  9.452476e-13
# min     933.000000     5.000000     0.000000     0.000000  3.397370e+01
# 25%    4051.000000     7.000000     5.000000     0.000000  3.397370e+01
# 50%    4104.000000    12.000000     9.000000     0.000000  3.397370e+01
# 75%    4302.000000    25.000000    18.000000     4.000000  3.397370e+01
# max    4388.000000   194.000000   125.000000    33.000000  3.397370e+01
#
#            col_long  col_rank      sch_lat     sch_long            d
# count  2.094000e+03    2094.0  2094.000000  2094.000000  2094.000000
# mean  -1.173281e+02       8.0    35.169236  -119.149868   243.264603
# std    5.685700e-12       0.0     1.743609     1.982689   235.500532
# min   -1.173281e+02       8.0    32.744744  -124.195310    10.316797
# 25%   -1.173281e+02       8.0    33.884924  -121.422550    55.547694
# 50%   -1.173281e+02       8.0    34.147006  -118.186258    92.819577
# 75%   -1.173281e+02       8.0    37.319540  -117.775946   561.235841
# max   -1.173281e+02       8.0    40.698314  -115.503774   963.677957
#
#
# college ranking:  9
#
#            ceeb_id     app_val     adm_val     enr_val       col_lat  \
# count   718.000000  718.000000  718.000000  718.000000  7.180000e+02
# mean   4142.782730   12.071031    7.635097    0.151811  3.736610e+01
# std     250.778009   10.596398    7.104755    0.720736  4.621747e-13
# min    2830.000000    5.000000    0.000000    0.000000  3.736610e+01
# 25%    4070.000000    6.000000    4.000000    0.000000  3.736610e+01
# 50%    4252.000000    9.000000    6.000000    0.000000  3.736610e+01
# 75%    4302.000000   14.000000    9.000000    0.000000  3.736610e+01
# max    4358.000000   92.000000   61.000000    6.000000  3.736610e+01
#
#            col_long  col_rank     sch_lat    sch_long           d
# count  7.180000e+02     718.0  718.000000  718.000000  718.000000
# mean  -1.204224e+02       9.0   35.803748 -119.923985  285.014640
# std    2.844152e-14       0.0    1.829144    1.917844  148.764676
# min   -1.204224e+02       9.0   32.744744 -122.578786   74.173058
# 25%   -1.204224e+02       9.0   33.886374 -122.045055  150.794669
# 50%   -1.204224e+02       9.0   35.407914 -119.797870  228.546654
# 75%   -1.204224e+02       9.0   37.360278 -118.148088  431.422648
# max   -1.204224e+02       9.0   39.647498 -115.503774  675.016864

# %% [markdown]
# # Data Preparation

# %%
from sklearn.preprocessing import StandardScaler 

X = df.drop(["ceeb_id", "fullname", "campus", "city.x", "fall_term", "ethcat"], axis = 1)
X = pd.get_dummies(X, drop_first=True)
scaler = StandardScaler()
cols = X.columns
X = pd.DataFrame(scaler.fit_transform(X))
X.columns = cols
y = df["col_rank"]

# %%
df.head()
# Out:
#    ceeb_id                        fullname         campus           city.x  \
# 0      470          NATIONAL UNIVERSITY470      San Diego         La Jolla
# 1      933  COASTLINE COMMUNITY COLLEGE933       Berkeley  Fountain Valley
# 2      933  COASTLINE COMMUNITY COLLEGE933    Los Angeles  Fountain Valley
# 3      933  COASTLINE COMMUNITY COLLEGE933  Santa Barbara  Fountain Valley
# 4      933  COASTLINE COMMUNITY COLLEGE933      Riverside  Fountain Valley
#
#   fall_term                  school_name ethcat  app_val  adm_val  enr_val  \
# 0  9/1/2013          NATIONAL UNIVERSITY  White        6        0        0
# 1  9/1/2015  COASTLINE COMMUNITY COLLEGE  Asian       10        0        0
# 2  9/1/2015  COASTLINE COMMUNITY COLLEGE  White        7        0        0
# 3  9/1/2015  COASTLINE COMMUNITY COLLEGE  Asian       12        6        0
# 4  9/1/2016  COASTLINE COMMUNITY COLLEGE  Asian       15        4        0
#
#    col_lat  col_long  col_rank    sch_lat    sch_long           d
# 0  32.8801 -117.2340         3  32.829481 -117.127251   11.464280
# 1  37.8719 -122.2585         1  33.715600 -117.929238  605.606830
# 2  34.0689 -118.4452         2  33.715600 -117.929238   61.811813
# 3  34.4140 -119.8489         5  33.715600 -117.929238  193.361754
# 4  33.9737 -117.3281         8  33.715600 -117.929238   62.572713

# %% [markdown]
# # Modelling & Evaluation
